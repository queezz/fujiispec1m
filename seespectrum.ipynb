# %%
import mkse as mk
from importlib import reload
reload(mk)
# mk.mkses.basepathis(r"\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20221122_calibration")
# mk.mkses.basepathis(r'\\10.249.254.51\Public\BACK_UP\kurokawa\data\spectrometer\20230908')
# mk.mkses.basepathis(r'\\10.249.254.51\Public\BACK_UP\hayashi\workspace\data\Raman\20241122')
mk.mkses.basepathis(r'\\10.249.254.51\Public\BACK_UP\wang')
# mk.mkses.basepathis(r'\\10.249.254.51\Public\BACK_UP\hashizuka\thesis(master)\data\Czerny\1115')
# mk.mkses.basepathis(r'C:\Users\fujii\Documents\python\kuzmin\hayashi\0121')
# mk.mkses.basepathis(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20221227_Xu3')
# print(mk.mkses.basefiles)
# mk.display_nc(mk.mkses.basefiles[0])

# mk.display_nc_all()

# mk.display_nc(name="O2lamp-256000-1000.0ms-.nc")
# mk.display_nc(name="NiO-488000-60000.0ms-.nc")
# mk.display_nc(name="NiO-463000-300000.0ms-.nc",ylimit=[914000,925000])
mk.display_nc(name="pla-411000-100ms-.nc")
# mk.display_nc(name="pla-322000-45000.0ms-1550-.nc",ylimit=[910000,911500])
# mk.display_nc(name="pla-312000-45000.0ms-1550-.nc",ylimit=[910000,911500])
# mk.display_nc(name="pla-302000-45000.0ms-1550-.nc",ylimit=[910000,911500])
# mk.display_nc(name="pla-292000-45000.0ms-1550-.nc",ylimit=[910000,911500])
# mk.display_nc(name="pla-282000-45000.0ms-1550-.nc",ylimit=[910000,911500])
# mk.display_nc(name="10%-1-215000-600000.0ms-2A-10%-026.nc",ylimit=[960000,970000])
# mk.display_nc(name="20%-1-215000-1200000.0ms-2A-20%-2047.nc",ylimit=[950000,960000])
# mk.display_nc(name="30%-1-215000-600000.0ms-2A-30%-2035.nc",ylimit=[940000,950000])

# mk.display_nc(name="afterO20%-215000-600000.0ms-.nc",ylimit=[940000,945000])
# mk.display_nc(name="O777-plasma-3e-3-213000-120000.0ms-.nc",ylimit=[940000,970000])
# mk.display_nc(name="O777-plasma-4e-3-213000-120000.0ms-.nc",ylimit=[940000,970000])
# mk.display_nc(name="O777-plasma-Arcleaning-213000-120000.0ms-.nc",ylimit=[940000,970000])
# mk.display_nc(name="O777-plasma-Arcleaning2-213000-120000.0ms-.nc",ylimit=[940000,970000])
# Out:
# 411000
# array([[9.47157000e+05, 9.47039000e+05, 9.46891000e+05, ...,
#         9.46667000e+05, 9.46294000e+05, 9.46764000e+05],
#        [6.59303094e+02, 6.59299576e+02, 6.59296058e+02, ...,
#         6.52017378e+02, 6.52013770e+02, 6.52010163e+02]])
