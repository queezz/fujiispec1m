# %%
# %run Spectrum_kuro.py
basepath = r"\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20230103"
# basepath = r'C:\Users\fujii\Documents\python\kuzmin\miura\20221225'
exception_word=["background"]
spec = Spectrometer(basepath,exception_word=exception_word)
# spec = Spectrometer(basepath)
spec.display(style=False) # OI + H spectrum

# %%
spec.subtract()
spec.df
# Out:
# c:\Users\fujii\Documents\python\kuzmin\kurokawa\lab_control\Spectrum_kuro.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df.loc[n]["data"] = subtract_background(fp=self.df.loc[n]["data"],disp=False,bp=join(background_path,background[0]))
#                                                 data   name  wavelenght(min)  \
# 0  [[1383.0, 1307.0, 1560.0, 1466.0, 1693.0, 1269...  alpha       652.192514
# 1  [[4323.0, 4240.0, 4242.0, 4168.0, 4033.0, 4127...   beta       487.804380
# 2  [[5916.0, 6511.0, 6492.0, 6067.0, 6903.0, 7074...  gamma       427.983632
# 3  [[7262.0, 7419.0, 6999.0, 6349.0, 5685.0, 5539...  delta       402.902562
#
#    wavelength(spectrum)  wavelenght(max)  rotation  \
# 0            656.050141       659.888396    411000
# ...

# %%
[display_nc(i) for i in spec.df["data"]]
# Out:
# [None, None, None, None]

# %%
# %run Spectrum_kuro.py
basepath = r"\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20230103"
display_all(basepath)
