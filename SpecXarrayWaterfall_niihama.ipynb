# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
from os.path import join, exists
import xarray as xr

# %%
#basepath = r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20210104_niihama_2'
basepath = r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20210216_yun\Duterium_plasma'
ls = os.listdir(basepath)

# %%
rcParams['font.size'] = 20

# %%
import os
from os.path import join
# %run imaging_tool.py

# %%
#basepath = r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20210127\35s
#basepath = r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20210127\20s'
#basepath = r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20210127\10s'
basepath = r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20210216_yun\Hydrogen_plasma\fulcher\25s'
#basepath = r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20210128_yun\Lamp'
ls = os.listdir(basepath)

# %%
#### %run imaging_tool.py
i = 0
ls = sorted(os.listdir(basepath))
ls = [i for i in ls if '440000' in i]

f = ls[i]
fp = join(basepath, f)
data = xr.open_dataset(fp)
image_data = data.to_array()[0]
plot_image(image_data)
#[ax.axvline(1030,c='C3',ls='--') for ax in gcf().axes]
#[ax.set_xlim(900,1100) for ax in gcf().axes]

# %%
a = image_data.data
imshow(a)
a.max()
# Out:
# 47704

# %%
2**16
# Out:
# 65536

# %%
gcf().set_size_inches([10,8])
plot(a.max(axis=0)/1e4)
ylim([0,6])
axhline(5.2)
grid()
gca().yaxis.set_minor_locator(MultipleLocator(1))

# %%
plot(image_data.sum(axis=0),'k.')

# %%
ls = sorted(os.listdir(basepath))
ls = [i for i in ls if '.nc' in i]
#ls = [i for i in ls if 'H2_' in i]
step = 6e4
fig=gcf()
fig.set_facecolor('w')
fig.set_size_inches([30,45])

for i,f in enumerate(ls[:]):
    fp = join(basepath, f)
    data = xr.open_dataset(fp)
    image_data = data.to_array()[0]
    plot(image_data.sum(axis=0)+i*step,'k')

    data.close()
#[text(-120,2.6e6+step*i,t[2:-3],color='r') for i,t in enumerate(ls)]
xlim(-170,2100)

xlabel('pixel')
ylabel('intensity')
#savefig('../img/hespectra.pdf',dpi=200,bbox_inches='tight')
# Out:
# Text(0, 0.5, 'intensity')

# %%
    data.to_array()[0]
# Out:
# <xarray.DataArray (y: 512, x: 2048)>
# array([[2032, 2041, 2031, ..., 2042, 2042, 2047],
#        [2046, 2043, 2049, ..., 2035, 2026, 2031],
#        [2026, 2037, 2027, ..., 2047, 2044, 2034],
#        ...,
#        [2051, 2044, 2037, ..., 2032, 2029, 2041],
#        [2052, 2047, 2044, ..., 2047, 2055, 2051],
#        [2064, 2054, 2295, ..., 2112, 2076, 2100]], dtype=uint16)
# Coordinates:
#     image_counter  int32 ...
#     variable       <U29 '__xarray_dataarray_variable__'
# Dimensions without coordinates: y, x

# %%
data.to_array()
# Out:
# <xarray.DataArray (variable: 1, y: 512, x: 2048)>
# array([[[2032, 2041, 2031, ..., 2042, 2042, 2047],
#         [2046, 2043, 2049, ..., 2035, 2026, 2031],
#         [2026, 2037, 2027, ..., 2047, 2044, 2034],
#         ...,
#         [2051, 2044, 2037, ..., 2032, 2029, 2041],
#         [2052, 2047, 2044, ..., 2047, 2055, 2051],
#         [2064, 2054, 2295, ..., 2112, 2076, 2100]]], dtype=uint16)
# Coordinates:
#     image_counter  int32 ...
#   * variable       (variable) <U29 '__xarray_dataarray_variable__'
# Dimensions without coordinates: y, x

# %%
#R = [f'{i}.fit' for i in [300000,301000,305000,310000,315000,350000,400000]]
R = [f'{300000 + 5000*i}.fit' for i in range(81)]

# %%
[i for i in R if '410000' in i or '415000' in i]
# Out:
# ['410000.fit', '415000.fit']

# %%
1000/300*1500
# Out:
# 5000.0
