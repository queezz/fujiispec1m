# %% [markdown]
# # 12/15 Balmer-${\gamma}$ spectra acquisiton
# Control both the stepping motor and the camera from this notebook.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from lab_control.spectrometer import thr640

# %%
from FLI import FLI
import numpy as np
import time
import logging
import csv
import xarray as xr
from os.path import join

# %%
# logger
logger = thr640.logger
camera = FLI()
step_motor = thr640.THR640()

# %%
count=635000 # バルマーγ
step_motor.goto(count)
step_motor.waitUntilReady()
# Out:
# 2020-12-18 14:50:28,786:INFO:getting status...
# 2020-12-18 14:50:35,656:INFO:Move to +635000
# 2020-12-18 14:50:35,758:INFO:getting status...
# 2020-12-18 14:50:41,788:INFO:getting status...

# %% [markdown]
# ### 1回目

# %%
for i in range(3): # i = 0,1,2
    
    # %run imaging_tool.py
    exposure = 1 * 1e3 # ms
    vbin = 1
    attributes = {
        "temperature": camera.getTemperature(),
        "device_status": camera.getDeviceStatus(),
        "exposure": exposure,
        "frame_type": "light",
    }
    
    camera.setExposureTime(exposure)
    camera.setVBin(vbin)
    camera.setImageArea(10,0,2058,512//vbin)
    time.sleep(.5)
    camera.exposeFrame()
    time.sleep(.1)
    # load image
    image_data = camera.grabFrame(out=np.empty((512//vbin,2048), np.uint16))
    # convert to xarray
    data = xr.DataArray(
        image_data, dims=["y", "x"], coords={"image_counter": 0}, attrs=attributes
    )
    
    if i == 0:
        filepath = 'Plasma_635000r_1000ms_1_1.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
        plot_image(image_data)
        
    elif i == 1:
        filepath = 'Plasma_635000r_1000ms_1_2.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
        
    elif i == 2:
        filepath = 'Plasma_635000r_1000ms_1_3.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)

# %% [markdown]
# ### 2回目

# %%
for i in range(3): # i = 0,1,2
    
    # %run imaging_tool.py
    exposure = 1 * 1e3 # ms
    vbin = 1
    attributes = {
        "temperature": camera.getTemperature(),
        "device_status": camera.getDeviceStatus(),
        "exposure": exposure,
        "frame_type": "light",
    }
    
    camera.setExposureTime(exposure)
    camera.setVBin(vbin)
    camera.setImageArea(10,0,2058,512//vbin)
    time.sleep(.5)
    camera.exposeFrame()
    time.sleep(.1)
    # load image
    image_data = camera.grabFrame(out=np.empty((512//vbin,2048), np.uint16))
    # convert to xarray
    data = xr.DataArray(
        image_data, dims=["y", "x"], coords={"image_counter": 0}, attrs=attributes
    )
    
    if i == 0:
        filepath = 'Plasma_635000r_1000ms_2_1.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
        plot_image(image_data)
        
    elif i == 1:
        filepath = 'Plasma_635000r_1000ms_2_2.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
        
    elif i == 2:
        filepath = 'Plasma_635000r_1000ms_2_3.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)

# %% [markdown]
# ### 3回目

# %%
for i in range(3): # i = 0,1,2
    
    # %run imaging_tool.py
    exposure = 1 * 1e3 # ms
    vbin = 1
    attributes = {
        "temperature": camera.getTemperature(),
        "device_status": camera.getDeviceStatus(),
        "exposure": exposure,
        "frame_type": "light",
    }
    
    camera.setExposureTime(exposure)
    camera.setVBin(vbin)
    camera.setImageArea(10,0,2058,512//vbin)
    time.sleep(.5)
    camera.exposeFrame()
    time.sleep(.1)
    # load image
    image_data = camera.grabFrame(out=np.empty((512//vbin,2048), np.uint16))
    # convert to xarray
    data = xr.DataArray(
        image_data, dims=["y", "x"], coords={"image_counter": 0}, attrs=attributes
    )
    
    if i == 0:
        filepath = 'Plasma_635000r_1000ms_3_1.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
        plot_image(image_data)
        
    elif i == 1:
        filepath = 'Plasma_635000r_1000ms_3_2.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
        
    elif i == 2:
        filepath = 'Plasma_635000r_1000ms_3_3.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)

# %% [markdown]
# ### 4回目

# %%
for i in range(3): # i = 0,1,2
    
    # %run imaging_tool.py
    exposure = 1 * 1e3 # ms
    vbin = 1
    attributes = {
        "temperature": camera.getTemperature(),
        "device_status": camera.getDeviceStatus(),
        "exposure": exposure,
        "frame_type": "light",
    }
    
    camera.setExposureTime(exposure)
    camera.setVBin(vbin)
    camera.setImageArea(10,0,2058,512//vbin)
    time.sleep(.5)
    camera.exposeFrame()
    time.sleep(.1)
    # load image
    image_data = camera.grabFrame(out=np.empty((512//vbin,2048), np.uint16))
    # convert to xarray
    data = xr.DataArray(
        image_data, dims=["y", "x"], coords={"image_counter": 0}, attrs=attributes
    )
    
    if i == 0:
        filepath = 'Plasma_635000r_1000ms_4_1.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
        plot_image(image_data)
        
    elif i == 1:
        filepath = 'Plasma_635000r_1000ms_4_2.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
        
    elif i == 2:
        filepath = 'Plasma_635000r_1000ms_4_3.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)

# %% [markdown]
# ### 5回目

# %%
for i in range(3): # i = 0,1,2
    
    # %run imaging_tool.py
    exposure = 1 * 1e3 # ms
    vbin = 1
    attributes = {
        "temperature": camera.getTemperature(),
        "device_status": camera.getDeviceStatus(),
        "exposure": exposure,
        "frame_type": "light",
    }
    
    camera.setExposureTime(exposure)
    camera.setVBin(vbin)
    camera.setImageArea(10,0,2058,512//vbin)
    time.sleep(.5)
    camera.exposeFrame()
    time.sleep(.1)
    # load image
    image_data = camera.grabFrame(out=np.empty((512//vbin,2048), np.uint16))
    # convert to xarray
    data = xr.DataArray(
        image_data, dims=["y", "x"], coords={"image_counter": 0}, attrs=attributes
    )
    
    if i == 0:
        filepath = 'Plasma_635000r_1000ms_5_1.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
        plot_image(image_data)
        
    elif i == 1:
        filepath = 'Plasma_635000r_1000ms_5_2.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
        
    elif i == 2:
        filepath = 'Plasma_635000r_1000ms_5_3.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)

# %% [markdown]
# 6回目

# %%
for i in range(3): # i = 0,1,2
    
    # %run imaging_tool.py
    exposure = 1 * 1e3 # ms
    vbin = 1
    attributes = {
        "temperature": camera.getTemperature(),
        "device_status": camera.getDeviceStatus(),
        "exposure": exposure,
        "frame_type": "light",
    }
    
    camera.setExposureTime(exposure)
    camera.setVBin(vbin)
    camera.setImageArea(10,0,2058,512//vbin)
    time.sleep(.5)
    camera.exposeFrame()
    time.sleep(.1)
    # load image
    image_data = camera.grabFrame(out=np.empty((512//vbin,2048), np.uint16))
    # convert to xarray
    data = xr.DataArray(
        image_data, dims=["y", "x"], coords={"image_counter": 0}, attrs=attributes
    )
    
    if i == 0:
        filepath = 'Plasma_635000r_1000ms_6_1.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
        plot_image(image_data)
        
    elif i == 1:
        filepath = 'Plasma_635000r_1000ms_6_2.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
        
    elif i == 2:
        filepath = 'Plasma_635000r_1000ms_6_3.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)

# %% [markdown]
# ### bg

# %%
for i in range(3): # i = 0,1,2
    
    # %run imaging_tool.py
    exposure = 1 * 1e3 # ms
    vbin = 1
    attributes = {
        "temperature": camera.getTemperature(),
        "device_status": camera.getDeviceStatus(),
        "exposure": exposure,
        "frame_type": "light",
    }
    
    camera.setExposureTime(exposure)
    camera.setVBin(vbin)
    camera.setImageArea(10,0,2058,512//vbin)
    time.sleep(.5)
    camera.exposeFrame()
    time.sleep(.1)
    # load image
    image_data = camera.grabFrame(out=np.empty((512//vbin,2048), np.uint16))
    # convert to xarray
    data = xr.DataArray(
        image_data, dims=["y", "x"], coords={"image_counter": 0}, attrs=attributes
    )
    
    if i == 0:
        filepath = 'Plasma_635000r_1000ms_bg_1.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
        plot_image(image_data)
        
    elif i == 1:
        filepath = 'Plasma_635000r_1000ms_bg_2.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
                
    elif i == 2:
        filepath = 'Plasma_635000r_1000ms_bg_3.nc'.format(count)
        filepath = join(r'\\10.249.254.51\Public\Kuzmin\Experiments-Leprecon\Spectrometer\20201218_yun\Hydrogen_plasma',filepath)
        data.to_netcdf(filepath)
